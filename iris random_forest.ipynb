# %%
from sklearn.datasets import load_iris
d=load_iris()

# %%
from sklearn.ensemble import RandomForestClassifier
mod=RandomForestClassifier()

# %%
import pandas as pd

# %%
df=pd.DataFrame(d.data, columns=d.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target']= d.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('target',axis='columns'),df.target,test_size=0.2)

# %%
mod.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
mod.score(X_test,y_test)
# Out:
# 1.0

# %%
from matplotlib import pyplot as plt

# %%
tree_to_visualize=0
from sklearn.tree import plot_tree
plot_tree(mod.estimators_[tree_to_visualize], filled=True, rounded=True,feature_names=d.feature_names, class_names=d.target_names)
# Out:
# [Text(0.375, 0.9166666666666666, 'petal length (cm) <= 2.45\ngini = 0.665\nsamples = 67\nvalue = [42, 42, 36]\nclass = setosa'),
#  Text(0.25, 0.75, 'gini = 0.0\nsamples = 23\nvalue = [42, 0, 0]\nclass = setosa'),
#  Text(0.5, 0.75, 'petal width (cm) <= 1.75\ngini = 0.497\nsamples = 44\nvalue = [0, 42, 36]\nclass = versicolor'),
#  Text(0.375, 0.5833333333333334, 'petal width (cm) <= 1.35\ngini = 0.311\nsamples = 25\nvalue = [0, 42, 10]\nclass = versicolor'),
#  Text(0.25, 0.4166666666666667, 'gini = 0.0\nsamples = 13\nvalue = [0, 30, 0]\nclass = versicolor'),
#  Text(0.5, 0.4166666666666667, 'petal length (cm) <= 4.95\ngini = 0.496\nsamples = 12\nvalue = [0, 12, 10]\nclass = versicolor'),
#  Text(0.25, 0.25, 'petal width (cm) <= 1.6\ngini = 0.198\nsamples = 7\nvalue = [0, 8, 1]\nclass = versicolor'),
#  Text(0.125, 0.08333333333333333, 'gini = 0.0\nsamples = 6\nvalue = [0, 8, 0]\nclass = versicolor'),
#  Text(0.375, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.75, 0.25, 'petal width (cm) <= 1.55\ngini = 0.426\nsamples = 5\nvalue = [0, 4, 9]\nclass = virginica'),
#  Text(0.625, 0.08333333333333333, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 9]\nclass = virginica'),
#  Text(0.875, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 4, 0]\nclass = versicolor'),
#  Text(0.625, 0.5833333333333334, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 26]\nclass = virginica')]
